# %% [markdown]
# # Project Idea 2:
# - A good loan (from the prospective of an investor) pays
# the interests and fractional principals on time and terminate at loan maturity.
# - An investor often lose money when a loan goes into default, settlement,
# or 'written off' (called **charged off** in this data set).
# - Build a supervised model to make **multi-label** prediction on 3 dimensions
# "charged off + default", "settlement involved", "hardship".
# - This can be used either by **Lending Club** itself or a third-party investing firm
# for loan-grade design or accurated portfolio selection.
# - Depending on the scope of your project, you may
#     - tackle a single label prediction.
#     - restrict to the pooled models.
#     - focus on the time seris models
# - This is a **multi-label** binary imbalance classification task.
# - If you train a **pooled** model, you have to deal with $2M+$ samples, often too
# large for a typical ML algorithm to handle.
#
# - Try several imbalance classification techniques and evaluate their performance.
#
# - Based on your business, discuss the negative impacts of type I (false
# positive), type II (false negative) errors in your prediction.
#
# - If you decide to train a time series model, make sure that you have some
# basic background on performing hyper-parameter tuning in the time series context.
#
# - **MUST**: A defaulted loan with a loan amount $\$1000$ has a totally different
# impact to the final profit than a defaulted $\$50000$ loan.
#    - Discuss whether the **classroom-taught** machine learning techniques
#     addresses these issues. How would you modify the classifier to take into account
#          - your business objectives.
#          - the profit and loss focus.
#
# - Can you use **NLP** technique to extract insights on the loan descriptions
# which helps your predictive task?
# </a><br>
# # Structure:
# - <a href="#preprocessing">Preprocessing</a><br>
#     - <a href="#before">Application Information before loan issued</a><br>
#     - <a href="#label">Lables</a><br>
#     - <a href="#missing">Missing Values</a><br>
# - <a href="#function">Function</a><br>
# - <a href="#ml">Machine Learning</a><br>
#     - Unsupervised Machine Learning
#         - <a href="#kmeans">K Means</a><br>
#
#     - Supervised Machine Learning
#         - <a href="#decision">Decision Tree</a><br>
#         - <a href="#rf">Random Forest</a><br>
#         - <a href="#svm">SVM</a><br>
#         - <a href="#xgboost">XGBoost</a><br>
#         - <a href="#logistic">Logistic Regression</a><br>
#         - <a href="#naive">Naive Bayes Classifier</a><br>
#         - <a href="#neighbor">Nearest Neighbor</a><br>
# - <a href="#imbalance">Handling Imbalanced Data</a><br>
#     - <a href="#smote">SMOTE</a><br>

# %%
import numpy as np
import pandas as pd

pd.options.display.max_columns = None
pd.options.display.max_rows = 100

# %%
df_raw_accepted = pd.read_csv('accepted_2007_to_2018Q4.csv')

# %%
df_raw_accepted.sample(frac=0.001).to_csv('sample_accepted.csv')

# %%
sample_accepted = pd.read_csv('sample_accepted.csv')

# %%
sample_accepted.shape

# %%
sample_accepted = sample_accepted.sample(2000)

# %% [markdown]
#  <p><a name="preprocessing"></a></p>
#
#  ## Preprocessing

# %%
df_processed = sample_accepted.copy()

# %% [markdown]
#  <p><a name="before"></a></p>
#
#  ### Application Information before loan is issued

# %%
# Secondary Applicant

joint_list = ['sec_app_fico_range_low','sec_app_fico_range_high',
               'sec_app_earliest_cr_line','sec_app_inq_last_6mths',
               'sec_app_mort_acc','sec_app_open_acc','sec_app_revol_util',
               'sec_app_open_act_il','sec_app_num_rev_accts','sec_app_chargeoff_within_12_mths',
               'sec_app_collections_12_mths_ex_med','sec_app_mths_since_last_major_derog',
               'verification_status_joint','revol_bal_joint', 
               'dti_joint', 'application_type','annual_inc_joint']

# %%
df_processed.loc[df_processed['application_type'] == 'Joint App',joint_list]
# Out:
#       sec_app_fico_range_low  sec_app_fico_range_high  \
# 1084                   745.0                    749.0
# 48                       NaN                      NaN
# 617                    670.0                    674.0
# 786                    625.0                    629.0
# 1222                   650.0                    654.0
# ...                      ...                      ...
# 53                     630.0                    634.0
# 498                    645.0                    649.0
# 888                    595.0                    599.0
# 1090                   675.0                    679.0
# 1819                     NaN                      NaN
#
#      sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 1084                 Jan-2008                     0.0               0.0
# 48                        NaN                     NaN               NaN
# 617                  Sep-1999                     2.0               3.0
# 786                  Oct-2008                     0.0               0.0
# 1222                 Sep-2011                     2.0               1.0
# ...                       ...                     ...               ...
# 53                   Sep-2002                     2.0               2.0
# 498                  Aug-2009                     0.0               1.0
# 888                  Oct-2006                     1.0               0.0
# 1090                 Nov-2001                     1.0               2.0
# 1819                      NaN                     NaN               NaN
#
#       sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 1084              10.0                 6.4                  2.0
# 48                 NaN                 NaN                  NaN
# 617                7.0                82.0                  3.0
# 786                6.0                69.8                  1.0
# 1222               8.0                35.5                  0.0
# ...                ...                 ...                  ...
# 53                 8.0                77.9                  4.0
# 498                4.0                43.2                  1.0
# 888               14.0                77.0                  4.0
# 1090              12.0                85.2                  2.0
# 1819               NaN                 NaN                  NaN
#
#       sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 1084                    9.0                               0.0
# 48                      NaN                               NaN
# 617                     3.0                               0.0
# 786                     6.0                               0.0
# 1222                   10.0                               0.0
# ...                     ...                               ...
# 53                      4.0                               0.0
# 498                     6.0                               0.0
# 888                    16.0                               0.0
# 1090                    7.0                               0.0
# 1819                    NaN                               NaN
#
#       sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 1084                                 0.0                                  NaN
# 48                                   NaN                                  NaN
# 617                                  0.0                                  NaN
# 786                                  0.0                                  NaN
# 1222                                 0.0                                  NaN
# ...                                  ...                                  ...
# 53                                   0.0                                 40.0
# 498                                  0.0                                 65.0
# 888                                  0.0                                  NaN
# 1090                                 0.0                                 37.0
# 1819                                 NaN                                  NaN
#
#      verification_status_joint  revol_bal_joint  dti_joint application_type  \
# 1084              Not Verified           6678.0      14.48        Joint App
# 48                Not Verified              NaN      32.11        Joint App
# 617               Not Verified          25384.0      13.49        Joint App
# 786               Not Verified          16287.0      19.24        Joint App
# 1222              Not Verified          19797.0      17.31        Joint App
# ...                        ...              ...        ...              ...
# 53                    Verified          43796.0      28.13        Joint App
# 498                   Verified            778.0       7.95        Joint App
# 888               Not Verified          22073.0      27.16        Joint App
# 1090              Not Verified          54167.0      25.70        Joint App
# 1819              Not Verified              NaN      18.92        Joint App
#
#       annual_inc_joint
# 1084           74000.0
# 48             93000.0
# 617           156000.0
# 786            67000.0
# 1222           97200.0
# ...                ...
# 53            140000.0
# 498            56000.0
# 888            75000.0
# 1090          192000.0
# 1819           98000.0
#
# [113 rows x 17 columns]

# %% [markdown]
#  <p><a name="label"></a></p>
#
#  ### Lables

# %%
# Multi Labels - "charged off + default", "settlement involved", "hardship" 

label_list = ['label_hardship','label_chargedoff_default','label_settlement', 'loan_status' ]
chargedoff_default_list = ['Charged Off','Default', 'Does not meet the credit policy. Status:Charged Off']
# need to based on whole dataset 

df_processed['label_hardship'] = df_processed['hardship_status'].apply(lambda x: 0 if x  is np.nan else 1)
df_processed['label_chargedoff_default'] = df_processed['loan_status'].apply(lambda x: 1 if x in chargedoff_default_list else 0)
df_processed['label_settlement'] = df_processed['settlement_status'].apply(lambda x: 0 if x  is np.nan else 1)

# %%
# Hardship Loans 

hardship_list = ['hardship_flag',
     'hardship_type',
     'hardship_reason',
     'hardship_status',
     'deferral_term',
     'hardship_amount',
     'hardship_start_date',
     'hardship_end_date',
     'payment_plan_start_date',
     'hardship_length',
     'hardship_dpd',
     'hardship_loan_status',
     'orig_projected_additional_accrued_interest',
     'hardship_payoff_balance_amount',
     'hardship_last_payment_amount',
     'label_hardship'
                ]

# %%
df_processed.loan_status.unique()
# Out:
# array(['Current', 'Fully Paid', 'Charged Off', 'In Grace Period',
#        'Late (31-120 days)', 'Late (16-30 days)',
#        'Does not meet the credit policy. Status:Charged Off'],
#       dtype=object)

# %%
df_processed[hardship_list][df_processed['hardship_type'].notnull()]
# Out:
#      hardship_flag                    hardship_type        hardship_reason  \
# 1057             N  INTEREST ONLY-3 MONTHS DEFERRAL          REDUCED_HOURS
# 492              N  INTEREST ONLY-3 MONTHS DEFERRAL     INCOME_CURTAILMENT
# 1567             N  INTEREST ONLY-3 MONTHS DEFERRAL       NATURAL_DISASTER
# 2157             N  INTEREST ONLY-3 MONTHS DEFERRAL                MEDICAL
# 1166             N  INTEREST ONLY-3 MONTHS DEFERRAL  EXCESSIVE_OBLIGATIONS
# 214              N  INTEREST ONLY-3 MONTHS DEFERRAL                MEDICAL
# 1861             N  INTEREST ONLY-3 MONTHS DEFERRAL  EXCESSIVE_OBLIGATIONS
# 680              N  INTEREST ONLY-3 MONTHS DEFERRAL           UNEMPLOYMENT
# 277              N  INTEREST ONLY-3 MONTHS DEFERRAL       NATURAL_DISASTER
#
#      hardship_status  deferral_term  hardship_amount hardship_start_date  \
# 1057          BROKEN            3.0           137.38            Aug-2018
# 492           BROKEN            3.0            93.56            Jan-2019
# 1567          BROKEN            3.0           112.33            Sep-2017
# 2157       COMPLETED            3.0            17.74            Jul-2017
# 1166          BROKEN            3.0           186.47            Aug-2018
# 214        COMPLETED            3.0           272.13            Jul-2018
# 1861       COMPLETED            3.0           233.03            May-2018
# 680        COMPLETED            3.0           279.08            Jul-2018
# 277        COMPLETED            3.0           152.74            Sep-2017
#
#      hardship_end_date payment_plan_start_date  hardship_length  hardship_dpd  \
# 1057          Oct-2018                Aug-2018              3.0          25.0
# 492           Jan-2019                Jan-2019              3.0          20.0
# 1567          Oct-2017                Sep-2017              3.0           0.0
# 2157          Sep-2017                Jul-2017              3.0          20.0
# 1166          Nov-2018                Sep-2018              3.0          11.0
# 214           Oct-2018                Aug-2018              3.0          20.0
# 1861          Aug-2018                May-2018              3.0          21.0
# 680           Oct-2018                Aug-2018              3.0           9.0
# 277           Dec-2017                Sep-2017              3.0           0.0
#
#      hardship_loan_status  orig_projected_additional_accrued_interest  \
# 1057    Late (16-30 days)                                         NaN
# 492     Late (16-30 days)                                         NaN
# 1567              Current                                         NaN
# 2157    Late (16-30 days)                                       53.22
# 1166      In Grace Period                                         NaN
# 214     Late (16-30 days)                                      816.39
# 1861    Late (16-30 days)                                      699.09
# 680       In Grace Period                                      837.24
# 277               Current                                      458.22
#
#       hardship_payoff_balance_amount  hardship_last_payment_amount
# 1057                        15311.53                        171.01
# 492                          9313.45                        117.98
# 1567                         7974.99                          1.36
# 2157                         1296.99                         22.75
# 1166                        15696.84                        235.24
# 214                         22180.82                        501.71
# 1861                        11048.50                        280.87
# 680                         25005.03                         65.15
# 277                         11563.74                        291.43

# %%
# Settlement Loans 

settlement_list = ['debt_settlement_flag',
     'debt_settlement_flag_date',
     'settlement_status',
     'settlement_date',
     'settlement_amount',
     'settlement_percentage',
     'settlement_term']

# %%
df_processed[settlement_list][df_processed['settlement_status'].notnull()]
# Out:
#      debt_settlement_flag debt_settlement_flag_date settlement_status  \
# 57                      Y                  Aug-2018            ACTIVE
# 1215                    Y                  Oct-2018            BROKEN
# 2062                    Y                  Oct-2018            ACTIVE
# 727                     Y                  Feb-2018            ACTIVE
# 1057                    Y                  Oct-2018            ACTIVE
# 846                     Y                  Jan-2018          COMPLETE
# 548                     Y                  Oct-2018          COMPLETE
# 598                     Y                  Apr-2017          COMPLETE
# 1126                    Y                  Mar-2018            ACTIVE
# 639                     Y                  Aug-2018            ACTIVE
# 192                     Y                  Oct-2017          COMPLETE
# 760                     Y                  Jun-2018            ACTIVE
# 107                     Y                  Jan-2019            BROKEN
# 930                     Y                  Nov-2018            ACTIVE
# 1170                    Y                  May-2016          COMPLETE
# 1166                    Y                  Dec-2018            ACTIVE
# 1289                    Y                  Mar-2019          COMPLETE
# 2194                    Y                  Dec-2018          COMPLETE
# 403                     Y                  Sep-2018            BROKEN
# 1810                    Y                  Jan-2019            ACTIVE
# 562                     Y                  Jul-2018            ACTIVE
# 911                     Y                  Jan-2019            ACTIVE
# 1587                    Y                  Dec-2018            ACTIVE
# 1874                    Y                  Jan-2019            ACTIVE
# 1498                    Y                  Feb-2018            ACTIVE
# 1226                    Y                  Oct-2018          COMPLETE
# 1160                    Y                  Oct-2018            ACTIVE
# 1659                    Y                  Jul-2018            BROKEN
# 1086                    Y                  Oct-2018          COMPLETE
# 885                     Y                  Jan-2019            BROKEN
# 1486                    Y                  Mar-2018          COMPLETE
# 1715                    Y                  Sep-2017            ACTIVE
# 1022                    Y                  Jan-2019            ACTIVE
#
#      settlement_date  settlement_amount  settlement_percentage  \
# 57          Aug-2018            1389.00                  60.00
# 1215        Nov-2017            3378.24                  50.00
# 2062        Oct-2018            8601.00                  50.00
# 727         Feb-2018            3769.00                  45.00
# 1057        Oct-2018            6900.00                  45.00
# 846         May-2017            2233.75                  45.00
# 548         Oct-2017            2246.00                  50.00
# 598         Mar-2017            1463.51                  45.00
# 1126        Mar-2018            4127.00                  50.00
# 639         Aug-2018            2986.00                  40.00
# 192         Apr-2017            5724.40                  45.00
# 760         Apr-2018            6446.91                  45.00
# 107         Nov-2018            5621.00                  45.00
# 930         Nov-2018            7608.00                  50.00
# 1170        Apr-2016            4328.95                  65.00
# 1166        Dec-2018            7285.00                  45.00
# 1289        Mar-2018            1980.00                  45.01
# 2194        Apr-2018            2859.00                  44.99
# 403         Oct-2017            1544.00                  45.03
# 1810        Dec-2018            4895.77                  45.00
# 562         Jul-2018            7532.00                  50.00
# 911         Jan-2019            3185.00                  45.01
# 1587        Dec-2018            4800.00                  45.00
# 1874        Jan-2019            1373.00                  50.00
# 1498        Feb-2018           12628.00                  45.00
# 1226        Apr-2018            1605.25                  40.00
# 1160        Oct-2018            5013.00                  45.01
# 1659        Feb-2018            4347.00                  40.00
# 1086        Oct-2017            4578.00                  45.00
# 885         Apr-2018           10335.00                  45.00
# 1486        Oct-2017             784.36                  45.00
# 1715        Aug-2017            4620.00                  60.00
# 1022        Jan-2019           10949.00                  65.00
#
#       settlement_term
# 57               12.0
# 1215             12.0
# 2062             18.0
# 727              14.0
# 1057             17.0
# 846               6.0
# 548              12.0
# 598               1.0
# 1126             18.0
# 639              12.0
# 192              24.0
# 760              24.0
# 107              18.0
# 930              24.0
# 1170              0.0
# 1166             12.0
# 1289             12.0
# 2194              8.0
# 403              15.0
# 1810             24.0
# 562              12.0
# 911              18.0
# 1587             18.0
# 1874             18.0
# 1498             18.0
# 1226              6.0
# 1160             12.0
# 1659             18.0
# 1086             12.0
# 885              18.0
# 1486             24.0
# 1715             24.0
# 1022             18.0

# %%
df_processed[label_list].sample(10)
# Out:
#       label_hardship  label_chargedoff_default  label_settlement  loan_status
# 77                 0                         0                 0   Fully Paid
# 974                0                         0                 0   Fully Paid
# 216                0                         0                 0   Fully Paid
# 53                 0                         0                 0   Fully Paid
# 1214               0                         0                 0   Fully Paid
# 202                0                         0                 0      Current
# 1532               0                         1                 0  Charged Off
# 1229               0                         0                 0   Fully Paid
# 722                0                         0                 0      Current
# 518                0                         0                 0   Fully Paid

# %% [markdown]
#  <p><a name="missing"></a></p>
#
# ### Missing Values

# %%
total = df_processed.isnull().sum().sort_values(ascending=False)
percent = (df_processed.isnull().sum()/df_processed.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(100)
# Out:
#                                             Total  Percent
# member_id                                    2000   1.0000
# orig_projected_additional_accrued_interest   1995   0.9975
# payment_plan_start_date                      1991   0.9955
# hardship_start_date                          1991   0.9955
# hardship_type                                1991   0.9955
# hardship_reason                              1991   0.9955
# hardship_status                              1991   0.9955
# deferral_term                                1991   0.9955
# hardship_last_payment_amount                 1991   0.9955
# hardship_payoff_balance_amount               1991   0.9955
# hardship_loan_status                         1991   0.9955
# hardship_dpd                                 1991   0.9955
# hardship_length                              1991   0.9955
# hardship_amount                              1991   0.9955
# hardship_end_date                            1991   0.9955
# sec_app_mths_since_last_major_derog          1977   0.9885
# settlement_term                              1967   0.9835
# settlement_percentage                        1967   0.9835
# debt_settlement_flag_date                    1967   0.9835
# settlement_status                            1967   0.9835
# settlement_date                              1967   0.9835
# settlement_amount                            1967   0.9835
# sec_app_revol_util                           1899   0.9495
# sec_app_open_acc                             1898   0.9490
# sec_app_fico_range_low                       1898   0.9490
# sec_app_fico_range_high                      1898   0.9490
# sec_app_earliest_cr_line                     1898   0.9490
# sec_app_inq_last_6mths                       1898   0.9490
# sec_app_mort_acc                             1898   0.9490
# revol_bal_joint                              1898   0.9490
# sec_app_open_act_il                          1898   0.9490
# sec_app_chargeoff_within_12_mths             1898   0.9490
# sec_app_collections_12_mths_ex_med           1898   0.9490
# sec_app_num_rev_accts                        1898   0.9490
# verification_status_joint                    1888   0.9440
# dti_joint                                    1887   0.9435
# annual_inc_joint                             1887   0.9435
# desc                                         1880   0.9400
# mths_since_last_record                       1691   0.8455
# mths_since_recent_bc_dlq                     1549   0.7745
# mths_since_last_major_derog                  1477   0.7385
# mths_since_recent_revol_delinq               1338   0.6690
# next_pymnt_d                                 1214   0.6070
# mths_since_last_delinq                       1017   0.5085
# il_util                                       944   0.4720
# mths_since_rcnt_il                            803   0.4015
# inq_fi                                        769   0.3845
# total_cu_tl                                   769   0.3845
# all_util                                      769   0.3845
# max_bal_bc                                    769   0.3845
# open_rv_24m                                   769   0.3845
# inq_last_12m                                  769   0.3845
# open_rv_12m                                   769   0.3845
# open_il_12m                                   769   0.3845
# total_bal_il                                  769   0.3845
# open_il_24m                                   769   0.3845
# open_act_il                                   769   0.3845
# open_acc_6m                                   769   0.3845
# mths_since_recent_inq                         263   0.1315
# emp_title                                     152   0.0760
# num_tl_120dpd_2m                              149   0.0745
# emp_length                                    127   0.0635
# mo_sin_old_il_acct                            122   0.0610
# percent_bc_gt_75                               75   0.0375
# mths_since_recent_bc                           74   0.0370
# bc_open_to_buy                                 74   0.0370
# bc_util                                        74   0.0370
# tot_cur_bal                                    68   0.0340
# tot_coll_amt                                   68   0.0340
# avg_cur_bal                                    68   0.0340
# total_rev_hi_lim                               68   0.0340
# num_tl_90g_dpd_24m                             68   0.0340
# num_bc_tl                                      68   0.0340
# tot_hi_cred_lim                                68   0.0340
# pct_tl_nvr_dlq                                 68   0.0340
# num_tl_op_past_12m                             68   0.0340
# num_tl_30dpd                                   68   0.0340
# num_rev_tl_bal_gt_0                            68   0.0340
# num_op_rev_tl                                  68   0.0340
# num_il_tl                                      68   0.0340
# num_rev_accts                                  68   0.0340
# total_il_high_credit_limit                     68   0.0340
# mo_sin_rcnt_tl                                 68   0.0340
# num_actv_bc_tl                                 68   0.0340
# num_accts_ever_120_pd                          68   0.0340
# mo_sin_old_rev_tl_op                           68   0.0340
# mo_sin_rcnt_rev_tl_op                          68   0.0340
# num_actv_rev_tl                                68   0.0340
# num_bc_sats                                    63   0.0315
# num_sats                                       63   0.0315
# mort_acc                                       52   0.0260
# total_bal_ex_mort                              52   0.0260
# acc_open_past_24mths                           52   0.0260
# total_bc_limit                                 52   0.0260
# title                                          19   0.0095
# dti                                             3   0.0015
# last_pymnt_d                                    1   0.0005
# pymnt_plan                                      0   0.0000
# url                                             0   0.0000
# loan_status                                     0   0.0000

# %%
# Drop irrelavant columns 
drop_list = ['Unnamed: 0','id','member_id','funded_amnt','url','desc','title']

drop_for_grade_list = ['funded_amnt_inv','int_rate','installment','issue_d','loan_status','pymnt_plan','out_prncp','out_prncp_inv']

df_processed = df_processed.drop(drop_list, axis=1)
df_processed = df_processed.drop(drop_for_grade_list, axis=1)

# Convert categorical to numerical 
df_processed['term'] = df_processed['term'].apply(lambda x: int(x.split()[0]))
df_processed['emp_length'] = df_processed['emp_length'].str.extract('(\d+)') 
#10 means more than 10 years 

# Convert to Datetime
df_processed['earliest_cr_line'] = pd.to_datetime(df_processed['earliest_cr_line'])

# Missing Values 

df_processed.mths_since_last_record = df_processed.mths_since_last_record.fillna(0)
df_processed.mths_since_last_delinq = df_processed.mths_since_last_delinq.fillna(0)

df_processed.emp_title = df_processed.emp_title.fillna('None')
df_processed.emp_length = df_processed.emp_length.fillna(0)

df_processed.revol_util = df_processed.revol_util.fillna(0)

df_processed.dti = df_processed.dti.fillna(df_processed.revol_bal / df_processed.annual_inc)
