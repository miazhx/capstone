# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

# %%
from matplotlib import pyplot as plt

# %%
accept_raw = pd.read_csv('accepted_2007_to_2016.csv.gz')
# Out:
# C:\Users\Laptop2\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (18,46,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Date manipulation

# %%
accept_raw['issue_date'] = pd.to_datetime(accept_raw['issue_d'])

# %%
from datetime import datetime as dt
from datetime import timedelta

# %%
accept_raw['issue_year'] = accept_raw['issue_date'].dt.year

# %%
accept_raw['issue_month'] = accept_raw['issue_date'].dt.month

# %%
accept_raw['issue_d'] = accept_raw['issue_date'].apply(lambda x: str(x)[:7])

# %%
accept_raw['term'] = accept_raw['term'].apply(lambda x: int(x.split()[0]))

# %%
accept_raw['last_pymnt_date'] = pd.to_datetime(accept_raw['last_pymnt_d'])

# %%
accept_raw[accept_raw['last_pymnt_d'].isna()].head().T
# Out:
#                                                                              26    \
# id                                                                        1069800
# member_id                                                             1.30468e+06
# loan_amnt                                                                   15000
# funded_amnt                                                                 15000
# funded_amnt_inv                                                              8725
# term                                                                           36
# int_rate                                                                    14.27
# installment                                                                514.64
# grade                                                                           C
# sub_grade                                                                      C2
# emp_title                                                             nyc transit
# emp_length                                                                9 years
# home_ownership                                                               RENT
# annual_inc                                                                  60000
# verification_status                                                  Not Verified
# issue_d                                                                   2011-12
# loan_status                                                           Charged Off
# pymnt_plan                                                                      n
# desc                              Borrower added on 12/15/11 > looking to cons...
# purpose                                                        debt_consolidation
# title                                                               consolidation
# zip_code                                                                    103xx
# addr_state                                                                     NY
# dti                                                                         15.22
# delinq_2yrs                                                                     0
# earliest_cr_line                                                         Oct-2003
# inq_last_6mths                                                                  1
# mths_since_last_delinq                                                        NaN
# mths_since_last_record                                                        NaN
# open_acc                                                                        7
# pub_rec                                                                         0
# revol_bal                                                                    5872
# revol_util                                                                   57.6
# total_acc                                                                      11
# initial_list_status                                                             f
# out_prncp                                                                       0
# out_prncp_inv                                                                   0
# total_pymnt                                                                     0
# total_pymnt_inv                                                                 0
# total_rec_prncp                                                                 0
# total_rec_int                                                                   0
# total_rec_late_fee                                                              0
# recoveries                                                                      0
# collection_recovery_fee                                                         0
# last_pymnt_d                                                                  NaN
# last_pymnt_amnt                                                                 0
# next_pymnt_d                                                                  NaN
# last_credit_pull_d                                                       Jan-2017
# collections_12_mths_ex_med                                                      0
# mths_since_last_major_derog                                                   NaN
# policy_code                                                                     1
# application_type                                                       INDIVIDUAL
# annual_inc_joint                                                              NaN
# dti_joint                                                                     NaN
# verification_status_joint                                                     NaN
# acc_now_delinq                                                                  0
# tot_coll_amt                                                                  NaN
# tot_cur_bal                                                                   NaN
# open_acc_6m                                                                   NaN
# open_il_6m                                                                    NaN
# open_il_12m                                                                   NaN
# open_il_24m                                                                   NaN
# mths_since_rcnt_il                                                            NaN
# total_bal_il                                                                  NaN
# il_util                                                                       NaN
# open_rv_12m                                                                   NaN
# open_rv_24m                                                                   NaN
# max_bal_bc                                                                    NaN
# all_util                                                                      NaN
# total_rev_hi_lim                                                              NaN
# inq_fi                                                                        NaN
# total_cu_tl                                                                   NaN
# inq_last_12m                                                                  NaN
# acc_open_past_24mths                                                          NaN
# avg_cur_bal                                                                   NaN
# bc_open_to_buy                                                                NaN
# bc_util                                                                       NaN
# chargeoff_within_12_mths                                                        0
# delinq_amnt                                                                     0
# mo_sin_old_il_acct                                                            NaN
# mo_sin_old_rev_tl_op                                                          NaN
# mo_sin_rcnt_rev_tl_op                                                         NaN
# mo_sin_rcnt_tl                                                                NaN
# mort_acc                                                                      NaN
# mths_since_recent_bc                                                          NaN
# mths_since_recent_bc_dlq                                                      NaN
# mths_since_recent_inq                                                         NaN
# mths_since_recent_revol_delinq                                                NaN
# num_accts_ever_120_pd                                                         NaN
# num_actv_bc_tl                                                                NaN
# num_actv_rev_tl                                                               NaN
# num_bc_sats                                                                   NaN
# num_bc_tl                                                                     NaN
# num_il_tl                                                                     NaN
# num_op_rev_tl                                                                 NaN
# num_rev_accts                                                                 NaN
# num_rev_tl_bal_gt_0                                                           NaN
# num_sats                                                                      NaN
# num_tl_120dpd_2m                                                              NaN
# num_tl_30dpd                                                                  NaN
# num_tl_90g_dpd_24m                                                            NaN
# num_tl_op_past_12m                                                            NaN
# pct_tl_nvr_dlq                                                                NaN
# percent_bc_gt_75                                                              NaN
# pub_rec_bankruptcies                                                            0
# tax_liens                                                                       0
# tot_hi_cred_lim                                                               NaN
# total_bal_ex_mort                                                             NaN
# total_bc_limit                                                                NaN
# total_il_high_credit_limit                                                    NaN
# issue_date                                                    2011-12-01 00:00:00
# issue_year                                                                   2011
# issue_month                                                                    12
# last_pymnt_date                                                               NaT
#
#                                                                              2731  \
# id                                                                        1032519
# member_id                                                             1.26216e+06
# loan_amnt                                                                    8000
# funded_amnt                                                                  8000
# funded_amnt_inv                                                              3975
# term                                                                           36
# int_rate                                                                    14.65
# installment                                                                275.96
# grade                                                                           C
# sub_grade                                                                      C3
# emp_title                                                           Southern Felt
# emp_length                                                              10+ years
# home_ownership                                                               RENT
# annual_inc                                                                  72000
# verification_status                                               Source Verified
# issue_d                                                                   2011-11
# loan_status                                                           Charged Off
# pymnt_plan                                                                      n
# desc                              Borrower added on 11/18/11 > Debt Consolidat...
# purpose                                                        debt_consolidation
# title                                                          bebt consolidation
# zip_code                                                                    278xx
# addr_state                                                                     NC
# dti                                                                         22.28
# delinq_2yrs                                                                     0
# earliest_cr_line                                                         Nov-1997
# inq_last_6mths                                                                  1
# mths_since_last_delinq                                                        NaN
# mths_since_last_record                                                        NaN
# open_acc                                                                       10
# pub_rec                                                                         0
# revol_bal                                                                   32955
# revol_util                                                                   85.8
# total_acc                                                                      31
# initial_list_status                                                             f
# out_prncp                                                                       0
# out_prncp_inv                                                                   0
# total_pymnt                                                                     0
# total_pymnt_inv                                                                 0
# total_rec_prncp                                                                 0
# total_rec_int                                                                   0
# total_rec_late_fee                                                              0
# recoveries                                                                      0
# collection_recovery_fee                                                         0
# last_pymnt_d                                                                  NaN
# last_pymnt_amnt                                                                 0
# next_pymnt_d                                                                  NaN
# last_credit_pull_d                                                       Jan-2017
# collections_12_mths_ex_med                                                      0
# mths_since_last_major_derog                                                   NaN
# policy_code                                                                     1
# application_type                                                       INDIVIDUAL
# annual_inc_joint                                                              NaN
# dti_joint                                                                     NaN
# verification_status_joint                                                     NaN
# acc_now_delinq                                                                  0
# tot_coll_amt                                                                  NaN
# tot_cur_bal                                                                   NaN
# open_acc_6m                                                                   NaN
# open_il_6m                                                                    NaN
# open_il_12m                                                                   NaN
# open_il_24m                                                                   NaN
# mths_since_rcnt_il                                                            NaN
# total_bal_il                                                                  NaN
# il_util                                                                       NaN
# open_rv_12m                                                                   NaN
# open_rv_24m                                                                   NaN
# max_bal_bc                                                                    NaN
# all_util                                                                      NaN
# total_rev_hi_lim                                                              NaN
# inq_fi                                                                        NaN
# total_cu_tl                                                                   NaN
# inq_last_12m                                                                  NaN
# acc_open_past_24mths                                                          NaN
# avg_cur_bal                                                                   NaN
# bc_open_to_buy                                                                NaN
# bc_util                                                                       NaN
# chargeoff_within_12_mths                                                        0
# delinq_amnt                                                                     0
# mo_sin_old_il_acct                                                            NaN
# mo_sin_old_rev_tl_op                                                          NaN
# mo_sin_rcnt_rev_tl_op                                                         NaN
# mo_sin_rcnt_tl                                                                NaN
# mort_acc                                                                      NaN
# mths_since_recent_bc                                                          NaN
# mths_since_recent_bc_dlq                                                      NaN
# mths_since_recent_inq                                                         NaN
# mths_since_recent_revol_delinq                                                NaN
# num_accts_ever_120_pd                                                         NaN
# num_actv_bc_tl                                                                NaN
# num_actv_rev_tl                                                               NaN
# num_bc_sats                                                                   NaN
# num_bc_tl                                                                     NaN
# num_il_tl                                                                     NaN
# num_op_rev_tl                                                                 NaN
# num_rev_accts                                                                 NaN
# num_rev_tl_bal_gt_0                                                           NaN
# num_sats                                                                      NaN
# num_tl_120dpd_2m                                                              NaN
# num_tl_30dpd                                                                  NaN
# num_tl_90g_dpd_24m                                                            NaN
# num_tl_op_past_12m                                                            NaN
# pct_tl_nvr_dlq                                                                NaN
# percent_bc_gt_75                                                              NaN
# pub_rec_bankruptcies                                                            0
# tax_liens                                                                       0
# tot_hi_cred_lim                                                               NaN
# total_bal_ex_mort                                                             NaN
# total_bc_limit                                                                NaN
# total_il_high_credit_limit                                                    NaN
# issue_date                                                    2011-11-01 00:00:00
# issue_year                                                                   2011
# issue_month                                                                    11
# last_pymnt_date                                                               NaT
#
#                                                      3625  \
# id                                                1016039
# member_id                                     1.24372e+06
# loan_amnt                                            6400
# funded_amnt                                          6400
# funded_amnt_inv                                      6400
# term                                                   60
# int_rate                                            18.25
# installment                                        163.39
# grade                                                   D
# sub_grade                                              D5
# emp_title                       akrons children hospitial
# emp_length                                        5 years
# home_ownership                                       RENT
# annual_inc                                          33000
# verification_status                       Source Verified
# issue_d                                           2011-11
# loan_status                                   Charged Off
# pymnt_plan                                              n
# desc                                                  NaN
# purpose                                    major_purchase
# title                                                loan
# zip_code                                            445xx
# addr_state                                             OH
# dti                                                  9.05
# delinq_2yrs                                             0
# earliest_cr_line                                 Jun-2006
# inq_last_6mths                                          3
# mths_since_last_delinq                                 25
# mths_since_last_record                                NaN
# open_acc                                                4
# pub_rec                                                 0
# revol_bal                                            2237
# revol_util                                           60.5
# total_acc                                               6
# initial_list_status                                     f
# out_prncp                                               0
# out_prncp_inv                                           0
# total_pymnt                                        366.75
# total_pymnt_inv                                    366.75
# total_rec_prncp                                         0
# total_rec_int                                           0
# total_rec_late_fee                                      0
# recoveries                                         366.75
# collection_recovery_fee                            66.015
# last_pymnt_d                                          NaN
# last_pymnt_amnt                                         0
# next_pymnt_d                                          NaN
# last_credit_pull_d                               Oct-2016
# collections_12_mths_ex_med                              0
# mths_since_last_major_derog                           NaN
# policy_code                                             1
# application_type                               INDIVIDUAL
# annual_inc_joint                                      NaN
# dti_joint                                             NaN
# verification_status_joint                             NaN
# acc_now_delinq                                          0
# tot_coll_amt                                          NaN
# tot_cur_bal                                           NaN
# open_acc_6m                                           NaN
# open_il_6m                                            NaN
# open_il_12m                                           NaN
# open_il_24m                                           NaN
# mths_since_rcnt_il                                    NaN
# total_bal_il                                          NaN
# il_util                                               NaN
# open_rv_12m                                           NaN
# open_rv_24m                                           NaN
# max_bal_bc                                            NaN
# all_util                                              NaN
# total_rev_hi_lim                                      NaN
# inq_fi                                                NaN
# total_cu_tl                                           NaN
# inq_last_12m                                          NaN
# acc_open_past_24mths                                  NaN
# avg_cur_bal                                           NaN
# bc_open_to_buy                                        NaN
# bc_util                                               NaN
# chargeoff_within_12_mths                                0
# delinq_amnt                                             0
# mo_sin_old_il_acct                                    NaN
# mo_sin_old_rev_tl_op                                  NaN
# mo_sin_rcnt_rev_tl_op                                 NaN
# mo_sin_rcnt_tl                                        NaN
# mort_acc                                              NaN
# mths_since_recent_bc                                  NaN
# mths_since_recent_bc_dlq                              NaN
# mths_since_recent_inq                                 NaN
# mths_since_recent_revol_delinq                        NaN
# num_accts_ever_120_pd                                 NaN
# num_actv_bc_tl                                        NaN
# num_actv_rev_tl                                       NaN
# num_bc_sats                                           NaN
# num_bc_tl                                             NaN
# num_il_tl                                             NaN
# num_op_rev_tl                                         NaN
# num_rev_accts                                         NaN
# num_rev_tl_bal_gt_0                                   NaN
# num_sats                                              NaN
# num_tl_120dpd_2m                                      NaN
# num_tl_30dpd                                          NaN
# num_tl_90g_dpd_24m                                    NaN
# num_tl_op_past_12m                                    NaN
# pct_tl_nvr_dlq                                        NaN
# percent_bc_gt_75                                      NaN
# pub_rec_bankruptcies                                    0
# tax_liens                                               0
# tot_hi_cred_lim                                       NaN
# total_bal_ex_mort                                     NaN
# total_bc_limit                                        NaN
# total_il_high_credit_limit                            NaN
# issue_date                            2011-11-01 00:00:00
# issue_year                                           2011
# issue_month                                            11
# last_pymnt_date                                       NaT
#
#                                                                              3998  \
# id                                                                        1009833
# member_id                                                             1.23659e+06
# loan_amnt                                                                   18000
# funded_amnt                                                                 18000
# funded_amnt_inv                                                             18000
# term                                                                           60
# int_rate                                                                    19.03
# installment                                                                467.23
# grade                                                                           E
# sub_grade                                                                      E2
# emp_title                                                               ZIMFA INC
# emp_length                                                                4 years
# home_ownership                                                               RENT
# annual_inc                                                                  36000
# verification_status                                                      Verified
# issue_d                                                                   2011-11
# loan_status                                                           Charged Off
# pymnt_plan                                                                      n
# desc                              Borrower added on 11/01/11 > pls make the fu...
# purpose                                                        debt_consolidation
# title                                                           debtconsolidation
# zip_code                                                                    061xx
# addr_state                                                                     CT
# dti                                                                          5.43
# delinq_2yrs                                                                     0
# earliest_cr_line                                                         Aug-2008
# inq_last_6mths                                                                  1
# mths_since_last_delinq                                                        NaN
# mths_since_last_record                                                        NaN
# open_acc                                                                       13
# pub_rec                                                                         0
# revol_bal                                                                    4545
# revol_util                                                                   18.6
# total_acc                                                                      17
# initial_list_status                                                             f
# out_prncp                                                                       0
# out_prncp_inv                                                                   0
# total_pymnt                                                                     0
# total_pymnt_inv                                                                 0
# total_rec_prncp                                                                 0
# total_rec_int                                                                   0
# total_rec_late_fee                                                              0
# recoveries                                                                      0
# collection_recovery_fee                                                         0
# last_pymnt_d                                                                  NaN
# last_pymnt_amnt                                                                 0
# next_pymnt_d                                                                  NaN
# last_credit_pull_d                                                       Jan-2017
# collections_12_mths_ex_med                                                      0
# mths_since_last_major_derog                                                   NaN
# policy_code                                                                     1
# application_type                                                       INDIVIDUAL
# annual_inc_joint                                                              NaN
# dti_joint                                                                     NaN
# verification_status_joint                                                     NaN
# acc_now_delinq                                                                  0
# tot_coll_amt                                                                  NaN
# tot_cur_bal                                                                   NaN
# open_acc_6m                                                                   NaN
# open_il_6m                                                                    NaN
# open_il_12m                                                                   NaN
# open_il_24m                                                                   NaN
# mths_since_rcnt_il                                                            NaN
# total_bal_il                                                                  NaN
# il_util                                                                       NaN
# open_rv_12m                                                                   NaN
# open_rv_24m                                                                   NaN
# max_bal_bc                                                                    NaN
# all_util                                                                      NaN
# total_rev_hi_lim                                                              NaN
# inq_fi                                                                        NaN
# total_cu_tl                                                                   NaN
# inq_last_12m                                                                  NaN
# acc_open_past_24mths                                                          NaN
# avg_cur_bal                                                                   NaN
# bc_open_to_buy                                                                NaN
# bc_util                                                                       NaN
# chargeoff_within_12_mths                                                        0
# delinq_amnt                                                                     0
# mo_sin_old_il_acct                                                            NaN
# mo_sin_old_rev_tl_op                                                          NaN
# mo_sin_rcnt_rev_tl_op                                                         NaN
# mo_sin_rcnt_tl                                                                NaN
# mort_acc                                                                      NaN
# mths_since_recent_bc                                                          NaN
# mths_since_recent_bc_dlq                                                      NaN
# mths_since_recent_inq                                                         NaN
# mths_since_recent_revol_delinq                                                NaN
# num_accts_ever_120_pd                                                         NaN
# num_actv_bc_tl                                                                NaN
# num_actv_rev_tl                                                               NaN
# num_bc_sats                                                                   NaN
# num_bc_tl                                                                     NaN
# num_il_tl                                                                     NaN
# num_op_rev_tl                                                                 NaN
# num_rev_accts                                                                 NaN
# num_rev_tl_bal_gt_0                                                           NaN
# num_sats                                                                      NaN
# num_tl_120dpd_2m                                                              NaN
# num_tl_30dpd                                                                  NaN
# num_tl_90g_dpd_24m                                                            NaN
# num_tl_op_past_12m                                                            NaN
# pct_tl_nvr_dlq                                                                NaN
# percent_bc_gt_75                                                              NaN
# pub_rec_bankruptcies                                                            0
# tax_liens                                                                       0
# tot_hi_cred_lim                                                               NaN
# total_bal_ex_mort                                                             NaN
# total_bc_limit                                                                NaN
# total_il_high_credit_limit                                                    NaN
# issue_date                                                    2011-11-01 00:00:00
# issue_year                                                                   2011
# issue_month                                                                    11
# last_pymnt_date                                                               NaT
#
#                                                                              4220
# id                                                                        1006579
# member_id                                                             1.23299e+06
# loan_amnt                                                                    1800
# funded_amnt                                                                  1800
# funded_amnt_inv                                                              1800
# term                                                                           36
# int_rate                                                                      8.9
# installment                                                                 57.16
# grade                                                                           A
# sub_grade                                                                      A5
# emp_title                                                       Hospira worldwide
# emp_length                                                                9 years
# home_ownership                                                               RENT
# annual_inc                                                                  50400
# verification_status                                                  Not Verified
# issue_d                                                                   2011-11
# loan_status                                                           Charged Off
# pymnt_plan                                                                      n
# desc                              Borrower added on 10/28/11 > I need this loa...
# purpose                                                                   wedding
# title                                                                     Wedding
# zip_code                                                                    917xx
# addr_state                                                                     CA
# dti                                                                          2.64
# delinq_2yrs                                                                     0
# earliest_cr_line                                                         Oct-1998
# inq_last_6mths                                                                  1
# mths_since_last_delinq                                                        NaN
# mths_since_last_record                                                        NaN
# open_acc                                                                        3
# pub_rec                                                                         0
# revol_bal                                                                    1930
# revol_util                                                                   16.1
# total_acc                                                                      10
# initial_list_status                                                             f
# out_prncp                                                                       0
# out_prncp_inv                                                                   0
# total_pymnt                                                                  1800
# total_pymnt_inv                                                              1800
# total_rec_prncp                                                                 0
# total_rec_int                                                                   0
# total_rec_late_fee                                                              0
# recoveries                                                                   1800
# collection_recovery_fee                                                         0
# last_pymnt_d                                                                  NaN
# last_pymnt_amnt                                                                 0
# next_pymnt_d                                                                  NaN
# last_credit_pull_d                                                       Jan-2017
# collections_12_mths_ex_med                                                      0
# mths_since_last_major_derog                                                   NaN
# policy_code                                                                     1
# application_type                                                       INDIVIDUAL
# annual_inc_joint                                                              NaN
# dti_joint                                                                     NaN
# verification_status_joint                                                     NaN
# acc_now_delinq                                                                  0
# tot_coll_amt                                                                  NaN
# tot_cur_bal                                                                   NaN
# open_acc_6m                                                                   NaN
# open_il_6m                                                                    NaN
# open_il_12m                                                                   NaN
# open_il_24m                                                                   NaN
# mths_since_rcnt_il                                                            NaN
# total_bal_il                                                                  NaN
# il_util                                                                       NaN
# open_rv_12m                                                                   NaN
# open_rv_24m                                                                   NaN
# max_bal_bc                                                                    NaN
# all_util                                                                      NaN
# total_rev_hi_lim                                                              NaN
# inq_fi                                                                        NaN
# total_cu_tl                                                                   NaN
# inq_last_12m                                                                  NaN
# acc_open_past_24mths                                                          NaN
# avg_cur_bal                                                                   NaN
# bc_open_to_buy                                                                NaN
# bc_util                                                                       NaN
# chargeoff_within_12_mths                                                        0
# delinq_amnt                                                                     0
# mo_sin_old_il_acct                                                            NaN
# mo_sin_old_rev_tl_op                                                          NaN
# mo_sin_rcnt_rev_tl_op                                                         NaN
# mo_sin_rcnt_tl                                                                NaN
# mort_acc                                                                      NaN
# mths_since_recent_bc                                                          NaN
# mths_since_recent_bc_dlq                                                      NaN
# mths_since_recent_inq                                                         NaN
# mths_since_recent_revol_delinq                                                NaN
# num_accts_ever_120_pd                                                         NaN
# num_actv_bc_tl                                                                NaN
# num_actv_rev_tl                                                               NaN
# num_bc_sats                                                                   NaN
# num_bc_tl                                                                     NaN
# num_il_tl                                                                     NaN
# num_op_rev_tl                                                                 NaN
# num_rev_accts                                                                 NaN
# num_rev_tl_bal_gt_0                                                           NaN
# num_sats                                                                      NaN
# num_tl_120dpd_2m                                                              NaN
# num_tl_30dpd                                                                  NaN
# num_tl_90g_dpd_24m                                                            NaN
# num_tl_op_past_12m                                                            NaN
# pct_tl_nvr_dlq                                                                NaN
# percent_bc_gt_75                                                              NaN
# pub_rec_bankruptcies                                                            0
# tax_liens                                                                       0
# tot_hi_cred_lim                                                               NaN
# total_bal_ex_mort                                                             NaN
# total_bc_limit                                                                NaN
# total_il_high_credit_limit                                                    NaN
# issue_date                                                    2011-11-01 00:00:00
# issue_year                                                                   2011
# issue_month                                                                    11
# last_pymnt_date                                                               NaT

# %%
accept_raw['paid_months'] = (accept_raw['last_pymnt_date'].dt.year - accept_raw['issue_date'].dt.year) * 12 + accept_raw['last_pymnt_date'].dt.month - accept_raw['issue_date'].dt.month

# %%
accept_raw.head().T
# Out:
#                                                                                 0  \
# id                                                                        1077501
# member_id                                                              1.2966e+06
# loan_amnt                                                                    5000
# funded_amnt                                                                  5000
# funded_amnt_inv                                                              4975
# term                                                                           36
# int_rate                                                                    10.65
# installment                                                                162.87
# grade                                                                           B
# sub_grade                                                                      B2
# emp_title                                                                     NaN
# emp_length                                                              10+ years
# home_ownership                                                               RENT
# annual_inc                                                                  24000
# verification_status                                                      Verified
# issue_d                                                                   2011-12
# loan_status                                                            Fully Paid
# pymnt_plan                                                                      n
# desc                              Borrower added on 12/22/11 > I need to upgra...
# purpose                                                               credit_card
# title                                                                    Computer
# zip_code                                                                    860xx
# addr_state                                                                     AZ
# dti                                                                         27.65
# delinq_2yrs                                                                     0
# earliest_cr_line                                                         Jan-1985
# inq_last_6mths                                                                  1
# mths_since_last_delinq                                                        NaN
# mths_since_last_record                                                        NaN
# open_acc                                                                        3
# pub_rec                                                                         0
# revol_bal                                                                   13648
# revol_util                                                                   83.7
# total_acc                                                                       9
# initial_list_status                                                             f
# out_prncp                                                                       0
# out_prncp_inv                                                                   0
# total_pymnt                                                               5863.16
# total_pymnt_inv                                                           5833.84
# total_rec_prncp                                                              5000
# total_rec_int                                                              863.16
# total_rec_late_fee                                                              0
# recoveries                                                                      0
# collection_recovery_fee                                                         0
# last_pymnt_d                                                             Jan-2015
# last_pymnt_amnt                                                            171.62
# next_pymnt_d                                                                  NaN
# last_credit_pull_d                                                       Jan-2017
# collections_12_mths_ex_med                                                      0
# mths_since_last_major_derog                                                   NaN
# policy_code                                                                     1
# application_type                                                       INDIVIDUAL
# annual_inc_joint                                                              NaN
# dti_joint                                                                     NaN
# verification_status_joint                                                     NaN
# acc_now_delinq                                                                  0
# tot_coll_amt                                                                  NaN
# tot_cur_bal                                                                   NaN
# open_acc_6m                                                                   NaN
# open_il_6m                                                                    NaN
# open_il_12m                                                                   NaN
# open_il_24m                                                                   NaN
# mths_since_rcnt_il                                                            NaN
# total_bal_il                                                                  NaN
# il_util                                                                       NaN
# open_rv_12m                                                                   NaN
# open_rv_24m                                                                   NaN
# max_bal_bc                                                                    NaN
# all_util                                                                      NaN
# total_rev_hi_lim                                                              NaN
# inq_fi                                                                        NaN
# total_cu_tl                                                                   NaN
# inq_last_12m                                                                  NaN
# acc_open_past_24mths                                                          NaN
# avg_cur_bal                                                                   NaN
# bc_open_to_buy                                                                NaN
# bc_util                                                                       NaN
# chargeoff_within_12_mths                                                        0
# delinq_amnt                                                                     0
# mo_sin_old_il_acct                                                            NaN
# mo_sin_old_rev_tl_op                                                          NaN
# mo_sin_rcnt_rev_tl_op                                                         NaN
# mo_sin_rcnt_tl                                                                NaN
# mort_acc                                                                      NaN
# mths_since_recent_bc                                                          NaN
# mths_since_recent_bc_dlq                                                      NaN
# mths_since_recent_inq                                                         NaN
# mths_since_recent_revol_delinq                                                NaN
# num_accts_ever_120_pd                                                         NaN
# num_actv_bc_tl                                                                NaN
# num_actv_rev_tl                                                               NaN
# num_bc_sats                                                                   NaN
# num_bc_tl                                                                     NaN
# num_il_tl                                                                     NaN
# num_op_rev_tl                                                                 NaN
# num_rev_accts                                                                 NaN
# num_rev_tl_bal_gt_0                                                           NaN
# num_sats                                                                      NaN
# num_tl_120dpd_2m                                                              NaN
# num_tl_30dpd                                                                  NaN
# num_tl_90g_dpd_24m                                                            NaN
# num_tl_op_past_12m                                                            NaN
# pct_tl_nvr_dlq                                                                NaN
# percent_bc_gt_75                                                              NaN
# pub_rec_bankruptcies                                                            0
# tax_liens                                                                       0
# tot_hi_cred_lim                                                               NaN
# total_bal_ex_mort                                                             NaN
# total_bc_limit                                                                NaN
# total_il_high_credit_limit                                                    NaN
# issue_date                                                    2011-12-01 00:00:00
# issue_year                                                                   2011
# issue_month                                                                    12
# last_pymnt_date                                               2015-01-01 00:00:00
# paid_months                                                                    37
#
#                                                                                 1  \
# id                                                                        1077430
# member_id                                                             1.31417e+06
# loan_amnt                                                                    2500
# funded_amnt                                                                  2500
# funded_amnt_inv                                                              2500
# term                                                                           60
# int_rate                                                                    15.27
# installment                                                                 59.83
# grade                                                                           C
# sub_grade                                                                      C4
# emp_title                                                                   Ryder
# emp_length                                                               < 1 year
# home_ownership                                                               RENT
# annual_inc                                                                  30000
# verification_status                                               Source Verified
# issue_d                                                                   2011-12
# loan_status                                                           Charged Off
# pymnt_plan                                                                      n
# desc                              Borrower added on 12/22/11 > I plan to use t...
# purpose                                                                       car
# title                                                                        bike
# zip_code                                                                    309xx
# addr_state                                                                     GA
# dti                                                                             1
# delinq_2yrs                                                                     0
# earliest_cr_line                                                         Apr-1999
# inq_last_6mths                                                                  5
# mths_since_last_delinq                                                        NaN
# mths_since_last_record                                                        NaN
# open_acc                                                                        3
# pub_rec                                                                         0
# revol_bal                                                                    1687
# revol_util                                                                    9.4
# total_acc                                                                       4
# initial_list_status                                                             f
# out_prncp                                                                       0
# out_prncp_inv                                                                   0
# total_pymnt                                                               1014.53
# total_pymnt_inv                                                           1014.53
# total_rec_prncp                                                            456.46
# total_rec_int                                                              435.17
# total_rec_late_fee                                                              0
# recoveries                                                                  122.9
# collection_recovery_fee                                                      1.11
# last_pymnt_d                                                             Apr-2013
# last_pymnt_amnt                                                            119.66
# next_pymnt_d                                                                  NaN
# last_credit_pull_d                                                       Oct-2016
# collections_12_mths_ex_med                                                      0
# mths_since_last_major_derog                                                   NaN
# policy_code                                                                     1
# application_type                                                       INDIVIDUAL
# annual_inc_joint                                                              NaN
# dti_joint                                                                     NaN
# verification_status_joint                                                     NaN
# acc_now_delinq                                                                  0
# tot_coll_amt                                                                  NaN
# tot_cur_bal                                                                   NaN
# open_acc_6m                                                                   NaN
# open_il_6m                                                                    NaN
# open_il_12m                                                                   NaN
# open_il_24m                                                                   NaN
# mths_since_rcnt_il                                                            NaN
# total_bal_il                                                                  NaN
# il_util                                                                       NaN
# open_rv_12m                                                                   NaN
# open_rv_24m                                                                   NaN
# max_bal_bc                                                                    NaN
# all_util                                                                      NaN
# total_rev_hi_lim                                                              NaN
# inq_fi                                                                        NaN
# total_cu_tl                                                                   NaN
# inq_last_12m                                                                  NaN
# acc_open_past_24mths                                                          NaN
# avg_cur_bal                                                                   NaN
# bc_open_to_buy                                                                NaN
# bc_util                                                                       NaN
# chargeoff_within_12_mths                                                        0
# delinq_amnt                                                                     0
# mo_sin_old_il_acct                                                            NaN
# mo_sin_old_rev_tl_op                                                          NaN
# mo_sin_rcnt_rev_tl_op                                                         NaN
# mo_sin_rcnt_tl                                                                NaN
# mort_acc                                                                      NaN
# mths_since_recent_bc                                                          NaN
# mths_since_recent_bc_dlq                                                      NaN
# mths_since_recent_inq                                                         NaN
# mths_since_recent_revol_delinq                                                NaN
# num_accts_ever_120_pd                                                         NaN
# num_actv_bc_tl                                                                NaN
# num_actv_rev_tl                                                               NaN
# num_bc_sats                                                                   NaN
# num_bc_tl                                                                     NaN
# num_il_tl                                                                     NaN
# num_op_rev_tl                                                                 NaN
# num_rev_accts                                                                 NaN
# num_rev_tl_bal_gt_0                                                           NaN
# num_sats                                                                      NaN
# num_tl_120dpd_2m                                                              NaN
# num_tl_30dpd                                                                  NaN
# num_tl_90g_dpd_24m                                                            NaN
# num_tl_op_past_12m                                                            NaN
# pct_tl_nvr_dlq                                                                NaN
# percent_bc_gt_75                                                              NaN
# pub_rec_bankruptcies                                                            0
# tax_liens                                                                       0
# tot_hi_cred_lim                                                               NaN
# total_bal_ex_mort                                                             NaN
# total_bc_limit                                                                NaN
# total_il_high_credit_limit                                                    NaN
# issue_date                                                    2011-12-01 00:00:00
# issue_year                                                                   2011
# issue_month                                                                    12
# last_pymnt_date                                               2013-04-01 00:00:00
# paid_months                                                                    16
#
#                                                    2  \
# id                                           1077175
# member_id                                1.31352e+06
# loan_amnt                                       2400
# funded_amnt                                     2400
# funded_amnt_inv                                 2400
# term                                              36
# int_rate                                       15.96
# installment                                    84.33
# grade                                              C
# sub_grade                                         C5
# emp_title                                        NaN
# emp_length                                 10+ years
# home_ownership                                  RENT
# annual_inc                                     12252
# verification_status                     Not Verified
# issue_d                                      2011-12
# loan_status                               Fully Paid
# pymnt_plan                                         n
# desc                                             NaN
# purpose                               small_business
# title                           real estate business
# zip_code                                       606xx
# addr_state                                        IL
# dti                                             8.72
# delinq_2yrs                                        0
# earliest_cr_line                            Nov-2001
# inq_last_6mths                                     2
# mths_since_last_delinq                           NaN
# mths_since_last_record                           NaN
# open_acc                                           2
# pub_rec                                            0
# revol_bal                                       2956
# revol_util                                      98.5
# total_acc                                         10
# initial_list_status                                f
# out_prncp                                          0
# out_prncp_inv                                      0
# total_pymnt                                  3005.67
# total_pymnt_inv                              3005.67
# total_rec_prncp                                 2400
# total_rec_int                                 605.67
# total_rec_late_fee                                 0
# recoveries                                         0
# collection_recovery_fee                            0
# last_pymnt_d                                Jun-2014
# last_pymnt_amnt                               649.91
# next_pymnt_d                                     NaN
# last_credit_pull_d                          Jan-2017
# collections_12_mths_ex_med                         0
# mths_since_last_major_derog                      NaN
# policy_code                                        1
# application_type                          INDIVIDUAL
# annual_inc_joint                                 NaN
# dti_joint                                        NaN
# verification_status_joint                        NaN
# acc_now_delinq                                     0
# tot_coll_amt                                     NaN
# tot_cur_bal                                      NaN
# open_acc_6m                                      NaN
# open_il_6m                                       NaN
# open_il_12m                                      NaN
# open_il_24m                                      NaN
# mths_since_rcnt_il                               NaN
# total_bal_il                                     NaN
# il_util                                          NaN
# open_rv_12m                                      NaN
# open_rv_24m                                      NaN
# max_bal_bc                                       NaN
# all_util                                         NaN
# total_rev_hi_lim                                 NaN
# inq_fi                                           NaN
# total_cu_tl                                      NaN
# inq_last_12m                                     NaN
# acc_open_past_24mths                             NaN
# avg_cur_bal                                      NaN
# bc_open_to_buy                                   NaN
# bc_util                                          NaN
# chargeoff_within_12_mths                           0
# delinq_amnt                                        0
# mo_sin_old_il_acct                               NaN
# mo_sin_old_rev_tl_op                             NaN
# mo_sin_rcnt_rev_tl_op                            NaN
# mo_sin_rcnt_tl                                   NaN
# mort_acc                                         NaN
# mths_since_recent_bc                             NaN
# mths_since_recent_bc_dlq                         NaN
# mths_since_recent_inq                            NaN
# mths_since_recent_revol_delinq                   NaN
# num_accts_ever_120_pd                            NaN
# num_actv_bc_tl                                   NaN
# num_actv_rev_tl                                  NaN
# num_bc_sats                                      NaN
# num_bc_tl                                        NaN
# num_il_tl                                        NaN
# num_op_rev_tl                                    NaN
# num_rev_accts                                    NaN
# num_rev_tl_bal_gt_0                              NaN
# num_sats                                         NaN
# num_tl_120dpd_2m                                 NaN
# num_tl_30dpd                                     NaN
# num_tl_90g_dpd_24m                               NaN
# num_tl_op_past_12m                               NaN
# pct_tl_nvr_dlq                                   NaN
# percent_bc_gt_75                                 NaN
# pub_rec_bankruptcies                               0
# tax_liens                                          0
# tot_hi_cred_lim                                  NaN
# total_bal_ex_mort                                NaN
# total_bc_limit                                   NaN
# total_il_high_credit_limit                       NaN
# issue_date                       2011-12-01 00:00:00
# issue_year                                      2011
# issue_month                                       12
# last_pymnt_date                  2014-06-01 00:00:00
# paid_months                                       30
#
#                                                                                 3  \
# id                                                                        1076863
# member_id                                                             1.27718e+06
# loan_amnt                                                                   10000
# funded_amnt                                                                 10000
# funded_amnt_inv                                                             10000
# term                                                                           36
# int_rate                                                                    13.49
# installment                                                                339.31
# grade                                                                           C
# sub_grade                                                                      C1
# emp_title                                                     AIR RESOURCES BOARD
# emp_length                                                              10+ years
# home_ownership                                                               RENT
# annual_inc                                                                  49200
# verification_status                                               Source Verified
# issue_d                                                                   2011-12
# loan_status                                                            Fully Paid
# pymnt_plan                                                                      n
# desc                              Borrower added on 12/21/11 > to pay for prop...
# purpose                                                                     other
# title                                                                    personel
# zip_code                                                                    917xx
# addr_state                                                                     CA
# dti                                                                            20
# delinq_2yrs                                                                     0
# earliest_cr_line                                                         Feb-1996
# inq_last_6mths                                                                  1
# mths_since_last_delinq                                                         35
# mths_since_last_record                                                        NaN
# open_acc                                                                       10
# pub_rec                                                                         0
# revol_bal                                                                    5598
# revol_util                                                                     21
# total_acc                                                                      37
# initial_list_status                                                             f
# out_prncp                                                                       0
# out_prncp_inv                                                                   0
# total_pymnt                                                               12231.9
# total_pymnt_inv                                                           12231.9
# total_rec_prncp                                                             10000
# total_rec_int                                                             2214.92
# total_rec_late_fee                                                          16.97
# recoveries                                                                      0
# collection_recovery_fee                                                         0
# last_pymnt_d                                                             Jan-2015
# last_pymnt_amnt                                                            357.48
# next_pymnt_d                                                                  NaN
# last_credit_pull_d                                                       Apr-2016
# collections_12_mths_ex_med                                                      0
# mths_since_last_major_derog                                                   NaN
# policy_code                                                                     1
# application_type                                                       INDIVIDUAL
# annual_inc_joint                                                              NaN
# dti_joint                                                                     NaN
# verification_status_joint                                                     NaN
# acc_now_delinq                                                                  0
# tot_coll_amt                                                                  NaN
# tot_cur_bal                                                                   NaN
# open_acc_6m                                                                   NaN
# open_il_6m                                                                    NaN
# open_il_12m                                                                   NaN
# open_il_24m                                                                   NaN
# mths_since_rcnt_il                                                            NaN
# total_bal_il                                                                  NaN
# il_util                                                                       NaN
# open_rv_12m                                                                   NaN
# open_rv_24m                                                                   NaN
# max_bal_bc                                                                    NaN
# all_util                                                                      NaN
# total_rev_hi_lim                                                              NaN
# inq_fi                                                                        NaN
# total_cu_tl                                                                   NaN
# inq_last_12m                                                                  NaN
# acc_open_past_24mths                                                          NaN
# avg_cur_bal                                                                   NaN
# bc_open_to_buy                                                                NaN
# bc_util                                                                       NaN
# chargeoff_within_12_mths                                                        0
# delinq_amnt                                                                     0
# mo_sin_old_il_acct                                                            NaN
# mo_sin_old_rev_tl_op                                                          NaN
# mo_sin_rcnt_rev_tl_op                                                         NaN
# mo_sin_rcnt_tl                                                                NaN
# mort_acc                                                                      NaN
# mths_since_recent_bc                                                          NaN
# mths_since_recent_bc_dlq                                                      NaN
# mths_since_recent_inq                                                         NaN
# mths_since_recent_revol_delinq                                                NaN
# num_accts_ever_120_pd                                                         NaN
# num_actv_bc_tl                                                                NaN
# num_actv_rev_tl                                                               NaN
# num_bc_sats                                                                   NaN
# num_bc_tl                                                                     NaN
# num_il_tl                                                                     NaN
# num_op_rev_tl                                                                 NaN
# num_rev_accts                                                                 NaN
# num_rev_tl_bal_gt_0                                                           NaN
# num_sats                                                                      NaN
# num_tl_120dpd_2m                                                              NaN
# num_tl_30dpd                                                                  NaN
# num_tl_90g_dpd_24m                                                            NaN
# num_tl_op_past_12m                                                            NaN
# pct_tl_nvr_dlq                                                                NaN
# percent_bc_gt_75                                                              NaN
# pub_rec_bankruptcies                                                            0
# tax_liens                                                                       0
# tot_hi_cred_lim                                                               NaN
# total_bal_ex_mort                                                             NaN
# total_bc_limit                                                                NaN
# total_il_high_credit_limit                                                    NaN
# issue_date                                                    2011-12-01 00:00:00
# issue_year                                                                   2011
# issue_month                                                                    12
# last_pymnt_date                                               2015-01-01 00:00:00
# paid_months                                                                    37
#
#                                                                                 4
# id                                                                        1075358
# member_id                                                             1.31175e+06
# loan_amnt                                                                    3000
# funded_amnt                                                                  3000
# funded_amnt_inv                                                              3000
# term                                                                           60
# int_rate                                                                    12.69
# installment                                                                 67.79
# grade                                                                           B
# sub_grade                                                                      B5
# emp_title                                                University Medical Group
# emp_length                                                                 1 year
# home_ownership                                                               RENT
# annual_inc                                                                  80000
# verification_status                                               Source Verified
# issue_d                                                                   2011-12
# loan_status                                                            Fully Paid
# pymnt_plan                                                                      n
# desc                              Borrower added on 12/21/11 > I plan on combi...
# purpose                                                                     other
# title                                                                    Personal
# zip_code                                                                    972xx
# addr_state                                                                     OR
# dti                                                                         17.94
# delinq_2yrs                                                                     0
# earliest_cr_line                                                         Jan-1996
# inq_last_6mths                                                                  0
# mths_since_last_delinq                                                         38
# mths_since_last_record                                                        NaN
# open_acc                                                                       15
# pub_rec                                                                         0
# revol_bal                                                                   27783
# revol_util                                                                   53.9
# total_acc                                                                      38
# initial_list_status                                                             f
# out_prncp                                                                       0
# out_prncp_inv                                                                   0
# total_pymnt                                                               4066.91
# total_pymnt_inv                                                           4066.91
# total_rec_prncp                                                              3000
# total_rec_int                                                             1066.91
# total_rec_late_fee                                                              0
# recoveries                                                                      0
# collection_recovery_fee                                                         0
# last_pymnt_d                                                             Jan-2017
# last_pymnt_amnt                                                              67.3
# next_pymnt_d                                                                  NaN
# last_credit_pull_d                                                       Jan-2017
# collections_12_mths_ex_med                                                      0
# mths_since_last_major_derog                                                   NaN
# policy_code                                                                     1
# application_type                                                       INDIVIDUAL
# annual_inc_joint                                                              NaN
# dti_joint                                                                     NaN
# verification_status_joint                                                     NaN
# acc_now_delinq                                                                  0
# tot_coll_amt                                                                  NaN
# tot_cur_bal                                                                   NaN
# open_acc_6m                                                                   NaN
# open_il_6m                                                                    NaN
# open_il_12m                                                                   NaN
# open_il_24m                                                                   NaN
# mths_since_rcnt_il                                                            NaN
# total_bal_il                                                                  NaN
# il_util                                                                       NaN
# open_rv_12m                                                                   NaN
# open_rv_24m                                                                   NaN
# max_bal_bc                                                                    NaN
# all_util                                                                      NaN
# total_rev_hi_lim                                                              NaN
# inq_fi                                                                        NaN
# total_cu_tl                                                                   NaN
# inq_last_12m                                                                  NaN
# acc_open_past_24mths                                                          NaN
# avg_cur_bal                                                                   NaN
# bc_open_to_buy                                                                NaN
# bc_util                                                                       NaN
# chargeoff_within_12_mths                                                        0
# delinq_amnt                                                                     0
# mo_sin_old_il_acct                                                            NaN
# mo_sin_old_rev_tl_op                                                          NaN
# mo_sin_rcnt_rev_tl_op                                                         NaN
# mo_sin_rcnt_tl                                                                NaN
# mort_acc                                                                      NaN
# mths_since_recent_bc                                                          NaN
# mths_since_recent_bc_dlq                                                      NaN
# mths_since_recent_inq                                                         NaN
# mths_since_recent_revol_delinq                                                NaN
# num_accts_ever_120_pd                                                         NaN
# num_actv_bc_tl                                                                NaN
# num_actv_rev_tl                                                               NaN
# num_bc_sats                                                                   NaN
# num_bc_tl                                                                     NaN
# num_il_tl                                                                     NaN
# num_op_rev_tl                                                                 NaN
# num_rev_accts                                                                 NaN
# num_rev_tl_bal_gt_0                                                           NaN
# num_sats                                                                      NaN
# num_tl_120dpd_2m                                                              NaN
# num_tl_30dpd                                                                  NaN
# num_tl_90g_dpd_24m                                                            NaN
# num_tl_op_past_12m                                                            NaN
# pct_tl_nvr_dlq                                                                NaN
# percent_bc_gt_75                                                              NaN
# pub_rec_bankruptcies                                                            0
# tax_liens                                                                       0
# tot_hi_cred_lim                                                               NaN
# total_bal_ex_mort                                                             NaN
# total_bc_limit                                                                NaN
# total_il_high_credit_limit                                                    NaN
# issue_date                                                    2011-12-01 00:00:00
# issue_year                                                                   2011
# issue_month                                                                    12
# last_pymnt_date                                               2017-01-01 00:00:00
# paid_months                                                                    61

# %% [markdown]
# ### Question
# - How does the issued loans vary year after year?
# - What are the purposes of applying **Lending Club** loans?
# - Do you observe different loan grade patterns for different loan purposes?
# - Do you observe different loan grade patterns in different years?
# - How about loan counts stratified into years and loan purposes/loan grades?

# %%
accept_raw['issue_year'] = accept_raw['issue_d'].apply(lambda x: x[4:])

# %%
def getDistribution(df, primary_key, secondary_key):
    cnt = df[primary_key].value_counts()
    print('Count by primary key: ', primary_key)
    print(cnt)
    print('------------------------------------')
    df_count1 = pd.DataFrame(df.groupby([primary_key, secondary_key]).count().iloc[:, 0])
    print('Count by {} (primary key) and {} (secondary key)'.format(primary_key, secondary_key))
    print(df_count1)
    print('------------------------------------')
    df_cnt_unstk_resetIdx = df_count1.unstack().reset_index()
    for val in sorted(accept_raw[primary_key].unique()):
        df_cnt_unstk_resetIdx[df_cnt_unstk_resetIdx[primary_key] == val]['id'].plot.bar(title = val)

# %%
df = accept_raw
primary_key = 'purpose'
secondary_key = 'grade'
getDistribution(df, primary_key, secondary_key)
# Out:
# Count by primary key:  purpose
# debt_consolidation    773152
# credit_card           297803
# home_improvement       83016
# other                  71365
# major_purchase         27683
# small_business         15168
# medical                13981
# car                    13677
# moving                  8644
# vacation                7998
# house                   5709
# wedding                 2349
# renewable_energy         879
# educational              423
# Name: purpose, dtype: int64
# ------------------------------------
# Count by purpose (primary key) and grade (secondary key)
#                               id
# purpose            grade
# car                A        3458
#                    B        4300
#                    C        3431
#                    D        1587
#                    E         648
#                    F         208
#                    G          45
# credit_card        A       72637
#                    B      106474
#                    C       75331
#                    D       29133
#                    E       10992
#                    F        2717
#                    G         519
# debt_consolidation A      107895
#                    B      218801
#                    C      231093
#                    D      126008
#                    E       63391
#                    F       21027
#                    G        4937
# educational        A          88
#                    B         112
#                    C         115
#                    D          52
#                    E          37
#                    F          11
#                    G           8
# home_improvement   A       16696
#                    B       24149
#                    C       22638
#                    D       11304
#                    E        5781
#                    F        1960
#                    G         488
# house              A         568
#                    B         980
#                    C        1383
#                    D        1163
#                    E         902
#                    F         485
#                    G         228
# major_purchase     A        6060
#                    B        7999
#                    C        7320
#                    D        3773
#                    E        1739
#                    F         632
#                    G         160
# medical            A        1535
#                    B        3492
#                    C        4469
#                    D        2666
#                    E        1261
#                    F         459
#                    G          99
# moving             A         617
#                    B        1581
#                    C        2680
#                    D        2144
#                    E        1076
#                    F         439
#                    G         107
# other              A        6861
#                    B       15972
#                    C       22262
#                    D       15068
#                    E        7381
#                    F        2937
#                    G         884
# renewable_energy   A          81
#                    B         168
#                    C         248
#                    D         198
#                    E         118
#                    F          54
#                    G          12
# small_business     A        1251
#                    B        2458
#                    C        3818
#                    D        3579
#                    E        2380
#                    F        1185
#                    G         497
# vacation           A         858
#                    B        2026
#                    C        2779
#                    D        1551
#                    E         588
#                    F         166
#                    G          30
# wedding            A         449
#                    B         553
#                    C         492
#                    D         506
#                    E         220
#                    F         103
#                    G          26
# ------------------------------------

# %%
df = accept_raw
primary_key = 'issue_year'
secondary_key = 'grade'
getDistribution(df, primary_key, secondary_key)
# Out:
# Count by primary key:  issue_year
# -10    144759
# -07    130195
# -11    122716
# -03    118094
# -12    116604
# -08    112802
# -04    106646
# -06     96893
# -05     96332
# -01     95191
# -02     91277
# -09     90338
# Name: issue_year, dtype: int64
# ------------------------------------
# Count by issue_year (primary key) and grade (secondary key)
#                      id
# issue_year grade
# -01        A      16927
#            B      28139
#            C      26168
#            D      14010
#            E       7087
#            F       2288
#            G        572
# -02        A      16035
#            B      27666
#            C      25642
#            D      12669
#            E       6536
#            F       2131
#            G        598
# -03        A      22354
#            B      33386
#            C      32746
#            D      16948
#            E       8798
#            F       3113
#            G        749
# -04        A      19671
#            B      29303
#            C      29965
#            D      16438
#            E       8019
#            F       2547
#            G        703
# -05        A      17112
#            B      27068
#            C      26495
#            D      14819
#            E       7637
#            F       2589
#            G        612
# -06        A      16599
#            B      28784
#            C      26832
#            D      14296
#            E       7196
#            F       2589
#            G        597
# -07        A      18573
#            B      37545
#            C      38475
#            D      21240
#            E      10141
#            F       3443
#            G        778
# -08        A      16101
#            B      35085
#            C      31851
#            D      17065
#            E       8553
#            F       3251
#            G        896
# -09        A      13623
#            B      26586
#            C      26458
#            D      13819
#            E       6745
#            F       2490
#            G        617
# -10        A      23828
#            B      42747
#            C      42377
#            D      21845
#            E      10018
#            F       3186
#            G        758
# -11        A      19553
#            B      37690
#            C      36455
#            D      18025
#            E       8118
#            F       2311
#            G        564
# -12        A      18678
#            B      35066
#            C      34595
#            D      17558
#            E       7666
#            F       2445
#            G        596
# ------------------------------------

# %%
df = accept_raw
primary_key = 'issue_year'
secondary_key = 'purpose'
getDistribution(df, primary_key, secondary_key)
# Out:
# Count by primary key:  issue_year
# -10    144759
# -07    130195
# -11    122716
# -03    118094
# -12    116604
# -08    112802
# -04    106646
# -06     96893
# -05     96332
# -01     95191
# -02     91277
# -09     90338
# Name: issue_year, dtype: int64
# ------------------------------------
# Count by issue_year (primary key) and purpose (secondary key)
#                                   id
# issue_year purpose
# -01        car                   848
#            credit_card         23046
#            debt_consolidation  56995
#            educational            35
#            home_improvement     4700
#            house                 371
#            major_purchase       1658
#            medical               926
#            moving                489
#            other                4347
#            renewable_energy       64
#            small_business       1149
#            vacation              423
#            wedding               140
# -02        car                   915
#            credit_card         22483
#            debt_consolidation  53640
#            educational            35
#            home_improvement     4940
#            house                 372
#            major_purchase       1771
#            medical               882
#            moving                458
#            other                4038
#            renewable_energy       60
#            small_business       1153
#            vacation              406
#            wedding               124
# -03        car                  1266
#            credit_card         27306
#            debt_consolidation  68260
#            educational            38
#            home_improvement     7679
#            house                 548
#            major_purchase       2608
#            medical              1162
#            moving                644
#            other                6210
#            renewable_energy       68
#            small_business       1470
#            vacation              651
#            wedding               184
# -04        car                  1105
#            credit_card         23624
#            debt_consolidation  61695
#            educational            35
#            home_improvement     7379
#            house                 525
#            major_purchase       2365
#            medical              1074
#            moving                706
#            other                6057
#            renewable_energy       61
#            small_business       1184
#            vacation              631
#            wedding               205
# -05        car                  1054
#            credit_card         21102
#            debt_consolidation  56340
#            educational            37
#            home_improvement     6709
#            house                 444
#            major_purchase       2038
#            medical              1045
#            moving                636
#            other                4930
#            renewable_energy       44
#            small_business       1101
#            vacation              649
#            wedding               203
# -06        car                  1075
#            credit_card         20659
#            debt_consolidation  56096
#            educational            37
#            home_improvement     7027
#            house                 443
#            major_purchase       2261
#            medical              1038
#            moving                756
#            other                5416
#            renewable_energy       68
#            small_business       1088
#            vacation              702
#            wedding               227
# -07        car                  1392
#            credit_card         28050
#            debt_consolidation  77179
#            educational            44
#            home_improvement     8388
#            house                 576
#            major_purchase       2663
#            medical              1298
#            moving                994
#            other                6942
#            renewable_energy       72
#            small_business       1286
#            vacation             1036
#            wedding               275
# -08        car                  1232
#            credit_card         24359
#            debt_consolidation  66232
#            educational            35
#            home_improvement     7084
#            house                 526
#            major_purchase       2455
#            medical              1098
#            moving                879
#            other                6581
#            renewable_energy       75
#            small_business       1217
#            vacation              752
#            wedding               277
# -09        car                  1043
#            credit_card         19369
#            debt_consolidation  52383
#            educational            33
#            home_improvement     5992
#            house                 408
#            major_purchase       2060
#            medical              1079
#            moving                691
#            other                5311
#            renewable_energy       70
#            small_business       1099
#            vacation              540
#            wedding               260
# -10        car                  1463
#            credit_card         32635
#            debt_consolidation  85905
#            educational            37
#            home_improvement     8868
#            house                 543
#            major_purchase       2766
#            medical              1568
#            moving                936
#            other                7514
#            renewable_energy      113
#            small_business       1506
#            vacation              751
#            wedding               154
# -11        car                  1119
#            credit_card         28164
#            debt_consolidation  71941
#            educational            30
#            home_improvement     7357
#            house                 425
#            major_purchase       2448
#            medical              1402
#            moving                709
#            other                6820
#            renewable_energy       95
#            small_business       1358
#            vacation              676
#            wedding               172
# -12        car                  1165
#            credit_card         27006
#            debt_consolidation  66486
#            educational            27
#            home_improvement     6893
#            house                 528
#            major_purchase       2590
#            medical              1409
#            moving                746
#            other                7199
#            renewable_energy       89
#            small_business       1557
#            vacation              781
#            wedding               128
# ------------------------------------

# %% [markdown]
# ### Question
# - How are the loan amounts/funded amounts distributed?
# - Are there variations across different loan purposes, loan grades, etc?
# - Are loans with higher funded amounts harder to be paid-in-full?

# %%
accept_raw.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'tax_liens', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit', 'issue_date', 'issue_year', 'issue_month',
#        'last_pymnt_date', 'paid_months'],
#       dtype='object', length=115)

# %%
plt.figure(figsize = (10, 8))
_ = plt.hist(accept_raw['loan_amnt'], bins = 20)
plt.title('Loan Amount', fontdict=None, loc='center')
# Out:
# Text(0.5, 1.0, 'Loan Amount')

# %%
plt.figure(figsize = (10, 8))
_ = plt.hist(accept_raw['funded_amnt'], bins = 20)
plt.title('Funded Amount', fontdict=None, loc='center')
# Out:
# Text(0.5, 1.0, 'Funded Amount')

# %% [markdown]
# ### distribution across different purposes or grades

# %%
primary_key = 'purpose'
secondary_key = 'loan_amnt'
print(accept_raw[primary_key].unique())
for val in sorted(accept_raw[primary_key].unique()):
    temp = accept_raw[accept_raw[primary_key] == val][[secondary_key]]
    plt.figure(figsize = (10, 8))
    _ = plt.hist(temp[secondary_key], bins = 20)
    plt.title(val, fontdict=None, loc='center')
# Out:
# ['credit_card' 'car' 'small_business' 'other' 'wedding'
#  'debt_consolidation' 'home_improvement' 'major_purchase' 'medical'
#  'moving' 'vacation' 'house' 'renewable_energy' 'educational']

# %%
primary_key = 'grade'
secondary_key = 'loan_amnt'
print(accept_raw[primary_key].unique())
for val in accept_raw[primary_key].unique():
    temp = accept_raw[accept_raw[primary_key] == val][[secondary_key]]
    plt.figure(figsize = (10, 8))
    _ = plt.hist(temp[secondary_key], bins = 20)
    plt.title(val, fontdict=None, loc='center')
# Out:
# ['B' 'C' 'A' 'E' 'F' 'D' 'G']

# %%
accept_raw['loan_status'].value_counts()
# Out:
# Current                                                783839
# Fully Paid                                             396204
# Charged Off                                             96554
# Late (31-120 days)                                      20073
# In Grace Period                                         10210
# Issued                                                   6048
# Late (16-30 days)                                        4555
# Does not meet the credit policy. Status:Fully Paid       1988
# Default                                                  1615
# Does not meet the credit policy. Status:Charged Off       761
# Name: loan_status, dtype: int64

# %%
#accept_raw[accept_raw['loan_status'] == 'In Grace Period']['issue_d'].value_counts()

# %%
accept_raw['loan_amt_log'] = accept_raw['loan_amnt'].apply(lambda x: int(np.log2(x)))

# %%
accept_raw['loan_amt_log'].value_counts()
# Out:
# 13    502768
# 14    402104
# 12    257041
# 11     70792
# 15     65408
# 10     19136
# 9       4587
# 8         11
# Name: loan_amt_log, dtype: int64

# %%
accept_status = accept_raw[~accept_raw['loan_status'].isin(['Current', 'In Grace Period', 'Issued'])]

# %%
df = accept_status
primary_key = 'loan_amt_log'
secondary_key = 'loan_status'
getDistribution(df, primary_key, secondary_key)
# Out:
# Count by primary key:  loan_amt_log
# 13    202569
# 14    148889
# 12    106823
# 11     30458
# 15     22767
# 10      8349
# 9       1884
# 8         11
# Name: loan_amt_log, dtype: int64
# ------------------------------------
# Count by loan_amt_log (primary key) and loan_status (secondary key)
#                                                                      id
# loan_amt_log loan_status
# 8            Does not meet the credit policy. Status:Charged...       1
#              Does not meet the credit policy. Status:Fully Paid       5
#              Fully Paid                                               5
# 9            Charged Off                                            230
#              Default                                                  5
#              Does not meet the credit policy. Status:Charged...      12
#              Does not meet the credit policy. Status:Fully Paid      29
#              Fully Paid                                            1553
#              Late (16-30 days)                                        9
#              Late (31-120 days)                                      46
# 10           Charged Off                                           1103
#              Default                                                 13
#              Does not meet the credit policy. Status:Charged...      36
#              Does not meet the credit policy. Status:Fully Paid     121
#              Fully Paid                                            6821
#              Late (16-30 days)                                       56
#              Late (31-120 days)                                     199
# 11           Charged Off                                           4692
#              Default                                                 72
#              Does not meet the credit policy. Status:Charged...      99
#              Does not meet the credit policy. Status:Fully Paid     347
#              Fully Paid                                           24260
#              Late (16-30 days)                                      190
#              Late (31-120 days)                                     798
# 12           Charged Off                                          16921
#              Default                                                262
#              Does not meet the credit policy. Status:Charged...     266
#              Does not meet the credit policy. Status:Fully Paid     655
#              Fully Paid                                           84742
#              Late (16-30 days)                                      714
#              Late (31-120 days)                                    3263
# 13           Charged Off                                          37416
#              Default                                                635
#              Does not meet the credit policy. Status:Charged...     237
#              Does not meet the credit policy. Status:Fully Paid     591
#              Fully Paid                                          154470
#              Late (16-30 days)                                     1626
#              Late (31-120 days)                                    7594
# 14           Charged Off                                          31240
#              Default                                                528
#              Does not meet the credit policy. Status:Charged...     110
#              Does not meet the credit policy. Status:Fully Paid     240
#              Fully Paid                                          108256
#              Late (16-30 days)                                     1648
#              Late (31-120 days)                                    6867
# 15           Charged Off                                           4952
#              Default                                                100
#              Fully Paid                                           16097
#              Late (16-30 days)                                      312
#              Late (31-120 days)                                    1306
# ------------------------------------

# %% [markdown]
# ### Question:
# - For borrowers, the most important factor is **interest rate** charged.
# - Provide insights on the **interest rates** dependence on loan grade/subgrade and term (36 or 60 months).
# - If the analysis is refined by separating loans with different start months
# (the year-month loan issuance date), report your finding.
# - Any rational explanation on why the **interest rate** should be grade/sub-grade
# dependent?
# - Any rational explanation on the time series variations of interest rates?
# - Any rational explanation why the interest rate rise w.r.t. loan term?

# %%
accept_raw.term.value_counts()
# Out:
# 36    944664
# 60    377183
# Name: term, dtype: int64

# %%
primary_key = 'term'
secondary_key = 'int_rate'
print(accept_raw[primary_key].unique())
for val in sorted(accept_raw[primary_key].unique()):
    temp = accept_raw[accept_raw[primary_key] == val][[secondary_key]]
    plt.figure(figsize = (10, 8))
    _ = plt.hist(temp[secondary_key], bins = 20)
    plt.title(val, fontdict=None, loc='center')
# Out:
# [36 60]

# %%
primary_key = 'grade'
secondary_key = 'int_rate'
print(accept_raw[primary_key].unique())
for val in sorted(accept_raw[primary_key].unique()):
    temp = accept_raw[accept_raw[primary_key] == val][[secondary_key]]
    plt.figure(figsize = (10, 8))
    _ = plt.hist(temp[secondary_key], bins = 20)
    plt.title(val, fontdict=None, loc='center')
# Out:
# ['B' 'C' 'A' 'E' 'F' 'D' 'G']

# %%
accept_raw.groupby(['issue_d'])['int_rate'].mean().plot()

# %%
accept_raw[['issue_year', 'int_rate']].boxplot(by='issue_year')

# %%
accept_raw[['grade', 'int_rate']].boxplot(by='grade')

# %% [markdown]
# ### Question:
# - For investors, it is crucial to know whether a loan is served to completion (loan_status 'Fully Paid').
# - Please analyze the percentages of non-completed loans in each loan grade/subgrade
# (i.e. default, charged off) which go beyond **delinquency**.
# - Provide justification the introduction of loan grade/subgrade.
# - Provide justification on the rate hike on riskier loan grade/subgrade.
# - What happens to percentage rates of loans involving settlement?
# - Make sure that your analysis takes into account of **loan-term**.

# %% [markdown]
# ### Question:
# - For investors, the **amortization process** returns the partial principal and
# monthly interest in a single montly installment payment.
# - Because the borrower can pre-pay the principal at-will or go belly-up (delinquent or default) at any
# moment within the loan term, it may shorten the loan duration un-expectedly or
# cause losses to the investors.
# - Thus it is vital for the investors to know the general pattern of loan-prepayment
# or delinquency (early stage leading to default or eventual charged off).
# - Please compute the actual durations of loans (last_payment_date - issuance_date)
# and
#     - analyze the pattern debtors terminate the loans before loan maturity
#     (either 'fully paid', or stop paying henceforth).
#     - Please include 'term', 'loan-grade/sub-grade' in your analysis.
# - Do you see major differences on the patterns with different loan-terms?
# What is the rational explanation for this difference?
#
# - Report the major characteristics of the patterns.
# - Do '60 months' (5 years) loans often get terminated at the end of the 5 years
# loan term? Why not?

# %%
df_early_term = accept_raw[(accept_raw['paid_months'] - accept_raw['term'] < 0) & accept_raw['loan_status'].isin(['Fully Paid', 'Charged Off', 'Default'])]

# %%
df_early_term['loan_status'].value_counts()
# Out:
# Fully Paid     332432
# Charged Off     95369
# Default          1589
# Name: loan_status, dtype: int64

# %%
df = df_early_term
primary_key = 'term'
secondary_key = 'loan_status'
getDistribution(df, primary_key, secondary_key)
# Out:
# Count by primary key:  term
# 36    314142
# 60    115248
# Name: term, dtype: int64
# ------------------------------------
# Count by term (primary key) and loan_status (secondary key)
#                       id
# term loan_status
# 36   Charged Off   58254
#      Default         955
#      Fully Paid   254933
# 60   Charged Off   37115
#      Default         634
#      Fully Paid    77499
# ------------------------------------

# %%
df = df_early_term
primary_key = 'grade'
secondary_key = 'loan_status'
getDistribution(df, primary_key, secondary_key)
# Out:
# Count by primary key:  grade
# B    119640
# C    117959
# D     71486
# A     64855
# E     37453
# F     14276
# G      3721
# Name: grade, dtype: int64
# ------------------------------------
# Count by grade (primary key) and loan_status (secondary key)
#                        id
# grade loan_status
# A     Charged Off    4926
#       Default          79
#       Fully Paid    59850
# B     Charged Off   17922
#       Default         283
#       Fully Paid   101435
# C     Charged Off   27639
#       Default         474
#       Fully Paid    89846
# D     Charged Off   22474
#       Default         350
#       Fully Paid    48662
# E     Charged Off   14404
#       Default         270
#       Fully Paid    22779
# F     Charged Off    6242
#       Default         105
#       Fully Paid     7929
# G     Charged Off    1762
#       Default          28
#       Fully Paid     1931
# ------------------------------------

# %%
# term60_over = accept_raw[(accept_raw['term'] == 60) & accept_raw['loan_status'].isin(['Fully Paid', 'Charged Off', 'Default'])]

# %% [markdown]
# ### Question:
# - For investors, the profitability of the loans is of their central
# concern.
# - For a given loan, the profit-and-loss (in percentages) can be computed as
# the (total_payment - principal)/principal.
# - For those loans which are eventually 'Fully Paid', what are the average
# returns (or the distributions of returns) of different loan grades/terms?
# - For those loans wich are default or beyond, what are the average returns or return distributions?
# - What about all the loans which have been
# terminated ('fully paid', 'default', 'charged off')?
# - What about the loans which end up in **loan settlement negotiations**?
# - Any variation of patterns for different loan purposes?
# - What happens if the issuance years are included in your analysis?
# - Is there any pattern between loan duration vs return rate?
